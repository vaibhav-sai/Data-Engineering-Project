# %% [markdown]
# ### Bronze to Silver Data Cleaning

# %%
# NOTEBOOK TITLE SILVER LAYER NOTEBOOK: DATA CLEANING AND INTEGRATION
# LOAD DATA FROM BRONZE LAYER
from pyspark.sql.functions import *
# Out:
# StatementMeta(, fc2ca070-eb90-4b4b-9e1a-526ade96b242, 3, Finished, Available, Finished, False)

# %% [markdown]
# ### Read Data from Lakehouse and store it in Dataframe

# %%
df_customers = spark.read.format("csv").option("header","true").load("abfss://292fd850-c68a-4bad-b4f3-7cabce198e06@onelake.dfs.fabric.microsoft.com/c04fc91a-073d-418d-b7fc-8db56290d615/Files/ShoppingMart_Bronze_Customers/ShoppingMart_customers.csv")
df_orders = spark.read.format("csv").option("header","true").load("abfss://292fd850-c68a-4bad-b4f3-7cabce198e06@onelake.dfs.fabric.microsoft.com/c04fc91a-073d-418d-b7fc-8db56290d615/Files/ShoppingMart_Bronze_Orders/ShoppingMart_orders.csv")
df_products = spark.read.format("csv").option("header","true").load("abfss://292fd850-c68a-4bad-b4f3-7cabce198e06@onelake.dfs.fabric.microsoft.com/c04fc91a-073d-418d-b7fc-8db56290d615/Files/ShoppingMart_Bronze_Products/ShoppingMart_products.csv")
df_reviews = spark.read.json("abfss://292fd850-c68a-4bad-b4f3-7cabce198e06@onelake.dfs.fabric.microsoft.com/c04fc91a-073d-418d-b7fc-8db56290d615/Files/ShoppingMart_Bronze_Reviews/ShoppingMart_review.json")
df_social = spark.read.json("abfss://292fd850-c68a-4bad-b4f3-7cabce198e06@onelake.dfs.fabric.microsoft.com/c04fc91a-073d-418d-b7fc-8db56290d615/Files/ShoppingMart_Bronze_Social_Media/ShoppingMart_social_media.json")
df_weblogs = spark.read.json("abfss://292fd850-c68a-4bad-b4f3-7cabce198e06@onelake.dfs.fabric.microsoft.com/c04fc91a-073d-418d-b7fc-8db56290d615/Files/ShoppingMart_Bronze_Web_Logs/ShoppingMart_web_logs.json")
# Out:
# StatementMeta(, fc2ca070-eb90-4b4b-9e1a-526ade96b242, 4, Finished, Available, Finished, False)

# %% [markdown]
# ### View the Dataframes

# %%
display(df_customers.limit(5))
# Out:
# StatementMeta(, fc2ca070-eb90-4b4b-9e1a-526ade96b242, 5, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, 3869743d-6ac7-4b3a-a57c-fe31830c7a35)

# %%
display(df_orders.limit(5))
# Out:
# StatementMeta(, fc2ca070-eb90-4b4b-9e1a-526ade96b242, 6, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, 4f003646-cd66-46b2-8c81-671f5386279c)

# %%
display(df_products.limit(5))
# Out:
# StatementMeta(, fc2ca070-eb90-4b4b-9e1a-526ade96b242, 7, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, c97ae4ba-8856-4e6c-bcc1-fdc004815e68)

# %%
display(df_reviews.limit(5))
# Out:
# StatementMeta(, fc2ca070-eb90-4b4b-9e1a-526ade96b242, 8, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, e686956f-7529-4fd7-b0df-d3c6dfb77297)

# %%
display(df_social.limit(5))
# Out:
# StatementMeta(, fc2ca070-eb90-4b4b-9e1a-526ade96b242, 9, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, faf8e5f9-e888-4db0-aa99-1b0f685f1541)

# %%
display(df_weblogs.limit(5))
# Out:
# StatementMeta(, fc2ca070-eb90-4b4b-9e1a-526ade96b242, 10, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, dfac3629-34a4-4710-aef6-890039f6ba81)

# %% [markdown]
# ### DATA CLEANING AND ENRICHING

# %%
df_orders = df_orders.dropna(subset = ["OrderID", "CustomerID", "ProductID", "OrderDate", "TotalAmount"])
df_orders = df_orders.withColumn("OrderDate", to_date(col("OrderDate")))
# display(df_orders)
# Out:
# StatementMeta(, fc2ca070-eb90-4b4b-9e1a-526ade96b242, 11, Finished, Available, Finished, False)

# %% [markdown]
# ### JOIN WITH PRODUCTS & CUSTOMERS

# %%
df_orders = df_orders \
    .join (df_customers, on = 'CustomerID', how = "inner") \
    .join (df_products, on = 'ProductID', how = "inner")
# Out:
# StatementMeta(, fc2ca070-eb90-4b4b-9e1a-526ade96b242, 12, Finished, Available, Finished, False)

# %%
display(df_orders.limit(5))
# Out:
# StatementMeta(, fc2ca070-eb90-4b4b-9e1a-526ade96b242, 13, Finished, Available, Finished, False)
# SynapseWidget(Synapse.DataFrame, b0f9e7e7-ab02-4e5f-8022-666c3254dc56)

# %% [markdown]
# ### WRITE DATA TO SILVER LAYER

# %%
df_orders.write.mode("overwrite").parquet("abfss://292fd850-c68a-4bad-b4f3-7cabce198e06@onelake.dfs.fabric.microsoft.com/e4be63a0-b193-4799-9364-384d3808141f/Files/ShoppingMart_Silver_Orders/ShoppingMart_customers_orderdata")
df_reviews.write.mode("overwrite").parquet("abfss://292fd850-c68a-4bad-b4f3-7cabce198e06@onelake.dfs.fabric.microsoft.com/e4be63a0-b193-4799-9364-384d3808141f/Files/ShoppingMart_Silver_Reviews/ShoppingMart_review")
df_social.write.mode("overwrite").parquet("abfss://292fd850-c68a-4bad-b4f3-7cabce198e06@onelake.dfs.fabric.microsoft.com/e4be63a0-b193-4799-9364-384d3808141f/Files/ShoppingMart_Silver_Social_Media/ShoppingMart_social_media")
df_weblogs.write.mode("overwrite").parquet("abfss://292fd850-c68a-4bad-b4f3-7cabce198e06@onelake.dfs.fabric.microsoft.com/e4be63a0-b193-4799-9364-384d3808141f/Files/ShoppingMart_Silver_Web_Logs/ShoppingMart_web_logs")
# Out:
# StatementMeta(, fc2ca070-eb90-4b4b-9e1a-526ade96b242, 14, Finished, Available, Finished, False)
